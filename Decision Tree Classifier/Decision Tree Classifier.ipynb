# %%
import csv
import sys
import pandas as pd
import numpy as np
from random import shuffle

# %%
def variety(rows):
    counts = {}
    for row in rows:
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts


def is_numeric(value):
    return isinstance(value, int) or isinstance(value, float)
  

def partition(rows, question):
    true, false = [], []
    for row in rows:
        if question.match(row):
            true.append(row)
        else:
            false.append(row)
    return true, false


def entropy(rows):
    counts = variety(rows)
    entropy = 0
    for label in counts:
        prob_of_lbl = counts[label] / float(len(rows))
        entropy += -prob_of_lbl * np.log(prob_of_lbl)
    return entropy


def information_gain(left, right, current_uncertainty):
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * entropy(left) - (1 - p) * entropy(right), - p * entropy(left) - (1 - p) * entropy(
        right)


def find_best_split(rows):
    best_gain = 0
    best_question = None
    current_uncertainty = entropy(rows)
    features_count = len(rows[0]) - 1

    # print("Entropy: ", current_uncertainty)

    for col in range(features_count):

        values = set([row[col] for row in rows])

        for val in values:

            question = Question(col, val)

            true, false = partition(rows, question)

            if len(true) == 0 or len(false) == 0:
                continue

            gain, remainder = information_gain(true, false, current_uncertainty)
            # print("Remainder: ", remainder)

            if gain >= best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question


def build_tree(rows):
    gain, question = find_best_split(rows)

    # print("Gain: ", gain)

    if gain == 0:
        return Leaf(rows)

    true, false = partition(rows, question)

    true_branch = build_tree(true)

    false_branch = build_tree(false)

    return DecisionNode(question, true_branch, false_branch)


def print_tree(node, spacing=""):
    if isinstance(node, Leaf):
        print(spacing + "Prediction", node.predictions)
        return

    print(spacing + str(node.question))

    print(spacing + ' Yes:')
    print_tree(node.true_branch, spacing + "  ")

    print(spacing + ' No:')
    print_tree(node.false_branch, spacing + "  ")


def classify(row, node):
    if isinstance(node, Leaf):
        return node.predictions

    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)


def print_leaf(counts):
    total = sum(counts.values()) * 1.0
    probs = {}
    for label in counts.keys():
        probs[label] = str(int(counts[label] / total * 100)) + "%"
    return probs


def radius_finder(continuous):
    continuous = list(continuous)
    max = sys.maxsize * (-1)
    min = sys.maxsize
    for i in range(0, continuous.__len__()):
        if float(continuous[i]) < min:
            min = float(continuous[i])
        elif float(continuous[i]) > max:
            max = float(continuous[i])
    radius = (max - min) / 3

    return radius


def map_continuous_discrete(continuous, radius):
    continuous = list(continuous)

    for i in range(0, continuous.__len__()):
        continuous[i] = float(continuous[i]) // radius
    return continuous


def combiner(lists):
    lists = list(lists)
    combined = []
    newList = []
    for i in range(0, lists[0].__len__() - 1):
        for j in range(0, lists.__len__()):
            newList.append(lists[j][i])
        combined.append(newList)
        newList = []
    return combined


def replacer(data, discrete, index):
    data = list(data)
    discrete = list(discrete)
    index = int(index)

    for i in range(0, data.__len__()):
        data[i][index] = discrete[i]
    return data

# %%
class Question:

    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            attributes[self.column], condition, str(self.value))
        
class Leaf:
    def __init__(self, rows):
        self.predictions = variety(rows)


class DecisionNode:

    def __init__(self, question, true_branch, false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
from google.colab import drive
drive.mount('/content/drive')

attributes = []
with open("/content/drive/MyDrive/Datasets/diabetes.csv", newline='') as f:
    reader = csv.reader(f)
    data = list(reader)
    attributes = data.pop(0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
combined = combiner(data)
for i in range(0, data[0].__len__() - 1):
    data = replacer(data, map_continuous_discrete(combined[i], radius_finder(combined[i])), i)

shuffle(data)

tree = build_tree(data[0:600])
print()
print("Decision Tree:")
print()
print_tree(tree)
# Out:
# Decision Tree:
#
# Is Glucose >= 2.0?
#  Yes:
#   Is BMI >= 1.0?
#    Yes:
#     Is BloodPressure >= 1.0?
#      Yes:
#       Is Age >= 4.0?
#        Yes:
#         Prediction {'0': 1}
#        No:
#         Is Age >= 2.0?
#          Yes:
#           Is Pregnancies >= 2.0?
#            Yes:
#             Prediction {'1': 4}
#            No:
#             Is Insulin >= 1.0?
#              Yes:
#               Is SkinThickness >= 1.0?
#                Yes:
#                 Is BloodPressure >= 2.0?
#                  Yes:
#                   Prediction {'1': 2}
#                  No:
#                   Is Age >= 3.0?
#                    Yes:
#                     Prediction {'1': 1}
#                    No:
#                     Is BMI >= 2.0?
#                      Yes:
#                       Prediction {'1': 1}
#                      No:
#                       Prediction {'0': 1, '1': 1}
#                No:
#                 Prediction {'1': 3}
#              No:
#               Is Age >= 3.0?
#                Yes:
#                 Is Pregnancies >= 1.0?
#                  Yes:
#                   Is BloodPressure >= 2.0?
#                    Yes:
#                     Prediction {'0': 1, '1': 1}
#                    No:
#                     Prediction {'0': 3}
#                  No:
#                   Is BloodPressure >= 2.0?
#                    Yes:
#                     Prediction {'1': 2}
#                    No:
#                     Is SkinThickness >= 3.0?
#                      Yes:
#                       Prediction {'1': 1}
#                      No:
#                       Prediction {'1': 2, '0': 3}
#                No:
#                 Is DiabetesPedigreeFunction >= 2.0?
#                  Yes:
#                   Prediction {'0': 1}
#                  No:
#                   Is SkinThickness >= 1.0?
#                    Yes:
#                     Is Pregnancies >= 1.0?
#                      Yes:
#                       Prediction {'1': 6}
#                      No:
#                       Is BMI >= 2.0?
#                        Yes:
#                         Prediction {'1': 1}
#                        No:
#                         Prediction {'0': 1}
#                    No:
#                     Is BMI >= 2.0?
#                      Yes:
#                       Is Pregnancies >= 1.0?
#                        Yes:
#                         Prediction {'1': 1}
#                        No:
#                         Prediction {'0': 2}
#                      No:
#                       Is Pregnancies >= 1.0?
#                        Yes:
#                         Is DiabetesPedigreeFunction >= 1.0?
#                          Yes:
#                           Prediction {'0': 2, '1': 2}
#                          No:
#                           Is BloodPressure >= 2.0?
#                            Yes:
#                             Prediction {'1': 5, '0': 1}
#                            No:
#                             Prediction {'1': 9, '0': 5}
#                        No:
#                         Is DiabetesPedigreeFunction >= 1.0?
#                          Yes:
#                           Prediction {'1': 3}
#                          No:
#                           Is BloodPressure >= 2.0?
#                            Yes:
#                             Prediction {'1': 2, '0': 1}
#                            No:
#                             Prediction {'1': 3, '0': 1}
#          No:
#           Is BloodPressure >= 2.0?
#            Yes:
#             Is Insulin >= 1.0?
#              Yes:
#               Prediction {'0': 4}
#              No:
#               Is BMI >= 2.0?
#                Yes:
#                 Prediction {'1': 3}
#                No:
#                 Is Pregnancies >= 2.0?
#                  Yes:
#                   Prediction {'0': 1}
#                  No:
#                   Is DiabetesPedigreeFunction >= 1.0?
#                    Yes:
#                     Prediction {'1': 1}
#                    No:
#                     Is Pregnancies >= 1.0?
#                      Yes:
#                       Is SkinThickness >= 1.0?
#                        Yes:
#                         Prediction {'1': 1, '0': 1}
#                        No:
#                         Prediction {'0': 2}
#                      No:
#                       Is SkinThickness >= 1.0?
#                        Yes:
#                         Prediction {'0': 4, '1': 3}
#                        No:
#                         Prediction {'1': 4, '0': 5}
#            No:
#             Is DiabetesPedigreeFunction >= 1.0?
#              Yes:
#               Is SkinThickness >= 1.0?
#                Yes:
#                 Prediction {'1': 6}
#                No:
#                 Is Insulin >= 1.0?
#                  Yes:
#                   Prediction {'1': 1}
#                  No:
#                   Is Pregnancies >= 1.0?
#                    Yes:
#                     Prediction {'1': 1}
#                    No:
#                     Prediction {'1': 3, '0': 1}
#              No:
#               Is Insulin >= 1.0?
#                Yes:
#                 Is SkinThickness >= 1.0?
#                  Yes:
#                   Prediction {'0': 2}
#                  No:
#                   Prediction {'1': 2, '0': 3}
#                No:
#                 Is Pregnancies >= 2.0?
#                  Yes:
#                   Prediction {'1': 1}
#                  No:
#                   Is BMI >= 2.0?
#                    Yes:
#                     Is Pregnancies >= 1.0?
#                      Yes:
#                       Prediction {'0': 1}
#                      No:
#                       Prediction {'1': 4}
#                    No:
#                     Is SkinThickness >= 1.0?
#                      Yes:
#                       Is Pregnancies >= 1.0?
#                        Yes:
#                         Prediction {'1': 1}
#                        No:
#                         Prediction {'1': 8, '0': 4}
#                      No:
#                       Is Pregnancies >= 1.0?
#                        Yes:
#                         Prediction {'1': 8, '0': 4}
#                        No:
#                         Prediction {'1': 13, '0': 9}
#      No:
#       Prediction {'1': 9}
#    No:
#     Prediction {'0': 5}
#  No:
#   Is Pregnancies >= 1.0?
#    Yes:
#     Is DiabetesPedigreeFunction >= 1.0?
#      Yes:
#       Is SkinThickness >= 1.0?
#        Yes:
#         Prediction {'1': 2}
#        No:
#         Is Pregnancies >= 2.0?
#          Yes:
#           Prediction {'1': 1}
#          No:
#           Is BloodPressure >= 2.0?
#            Yes:
#             Is Age >= 2.0?
#              Yes:
#               Prediction {'1': 1}
#              No:
#               Prediction {'0': 1}
#            No:
#             Is Age >= 2.0?
#              Yes:
#               Prediction {'0': 1, '1': 1}
#              No:
#               Prediction {'1': 4, '0': 2}
#      No:
#       Is Age >= 3.0?
#        Yes:
#         Prediction {'0': 4}
#        No:
#         Is Pregnancies >= 2.0?
#          Yes:
#           Is SkinThickness >= 1.0?
#            Yes:
#             Prediction {'0': 2}
#            No:
#             Is Age >= 2.0?
#              Yes:
#               Is BloodPressure >= 1.0?
#                Yes:
#                 Prediction {'1': 2, '0': 1}
#                No:
#                 Prediction {'1': 1}
#              No:
#               Prediction {'1': 1}
#          No:
#           Is SkinThickness >= 1.0?
#            Yes:
#             Is Age >= 2.0?
#              Yes:
#               Is BMI >= 2.0?
#                Yes:
#                 Prediction {'0': 1}
#                No:
#                 Is BloodPressure >= 2.0?
#                  Yes:
#                   Prediction {'0': 1, '1': 1}
#                  No:
#                   Is Glucose >= 1.0?
#                    Yes:
#                     Prediction {'1': 3, '0': 2}
#                    No:
#                     Prediction {'1': 1, '0': 1}
#              No:
#               Is BloodPressure >= 2.0?
#                Yes:
#                 Prediction {'0': 1}
#                No:
#                 Prediction {'0': 5, '1': 2}
#            No:
#             Is Glucose >= 1.0?
#              Yes:
#               Is BloodPressure >= 1.0?
#                Yes:
#                 Is BloodPressure >= 2.0?
#                  Yes:
#                   Is Age >= 2.0?
#                    Yes:
#                     Is BMI >= 1.0?
#                      Yes:
#                       Prediction {'0': 4}
#                      No:
#                       Prediction {'1': 1}
#                    No:
#                     Is BMI >= 1.0?
#                      Yes:
#                       Prediction {'1': 3, '0': 3}
#                      No:
#                       Prediction {'0': 1}
#                  No:
#                   Is BMI >= 1.0?
#                    Yes:
#                     Is Age >= 2.0?
#                      Yes:
#                       Prediction {'0': 13, '1': 5}
#                      No:
#                       Prediction {'0': 15, '1': 4}
#                    No:
#                     Prediction {'0': 1}
#                No:
#                 Is BMI >= 1.0?
#                  Yes:
#                   Prediction {'0': 3, '1': 2}
#                  No:
#                   Prediction {'0': 1, '1': 1}
#              No:
#               Prediction {'0': 2}
#    No:
#     Is BMI >= 1.0?
#      Yes:
#       Is Age >= 2.0?
#        Yes:
#         Is DiabetesPedigreeFunction >= 1.0?
#          Yes:
#           Prediction {'0': 4}
#          No:
#           Is SkinThickness >= 1.0?
#            Yes:
#             Prediction {'0': 2}
#            No:
#             Is Glucose >= 1.0?
#              Yes:
#               Is BloodPressure >= 2.0?
#                Yes:
#                 Is Age >= 3.0?
#                  Yes:
#                   Prediction {'1': 1}
#                  No:
#                   Prediction {'1': 1, '0': 1}
#                No:
#                 Is Age >= 3.0?
#                  Yes:
#                   Prediction {'0': 1}
#                  No:
#                   Prediction {'0': 6, '1': 8}
#              No:
#               Prediction {'0': 1}
#        No:
#         Is BMI >= 2.0?
#          Yes:
#           Is DiabetesPedigreeFunction >= 1.0?
#            Yes:
#             Is BloodPressure >= 2.0?
#              Yes:
#               Prediction {'1': 1, '0': 2}
#              No:
#               Prediction {'0': 1}
#            No:
#             Is BloodPressure >= 1.0?
#              Yes:
#               Is BloodPressure >= 2.0?
#                Yes:
#                 Is SkinThickness >= 1.0?
#                  Yes:
#                   Prediction {'0': 1, '1': 2}
#                  No:
#                   Prediction {'1': 1}
#                No:
#                 Prediction {'0': 1}
#              No:
#               Prediction {'1': 1}
#          No:
#           Is DiabetesPedigreeFunction >= 1.0?
#            Yes:
#             Is BloodPressure >= 2.0?
#              Yes:
#               Is SkinThickness >= 1.0?
#                Yes:
#                 Prediction {'0': 1, '1': 2}
#                No:
#                 Prediction {'1': 2}
#              No:
#               Is DiabetesPedigreeFunction >= 2.0?
#                Yes:
#                 Prediction {'0': 3}
#                No:
#                 Is SkinThickness >= 1.0?
#                  Yes:
#                   Prediction {'0': 6, '1': 2}
#                  No:
#                   Prediction {'0': 12, '1': 3}
#            No:
#             Is Insulin >= 1.0?
#              Yes:
#               Prediction {'0': 4}
#              No:
#               Is BloodPressure >= 2.0?
#                Yes:
#                 Is SkinThickness >= 1.0?
#                  Yes:
#                   Prediction {'0': 4}
#                  No:
#                   Is BloodPressure >= 3.0?
#                    Yes:
#                     Prediction {'0': 1}
#                    No:
#                     Prediction {'1': 2, '0': 19}
#                No:
#                 Is SkinThickness >= 1.0?
#                  Yes:
#                   Is Glucose >= 1.0?
#                    Yes:
#                     Prediction {'0': 26, '1': 6}
#                    No:
#                     Prediction {'0': 1}
#                  No:
#                   Is Glucose >= 1.0?
#                    Yes:
#                     Is BloodPressure >= 1.0?
#                      Yes:
#                       Prediction {'0': 128, '1': 16}
#                      No:
#                       Prediction {'0': 4, '1': 1}
#                    No:
#                     Prediction {'0': 3, '1': 1}
#      No:
#       Prediction {'0': 29}

# %%
testing_data = data[600:]

counter = 0
test_num = 1

for row in testing_data:
    print(
        "Test Number %d : \nReal Answer: %s , Prediction: %s" % (
            test_num, row[-1], print_leaf(classify(row, tree))), end=", ")
    test_num += 1
    if str(print_leaf(classify(row, tree)))[2].__eq__(str(row[-1])):
        print("Result : True")
        counter += 1
    else:
        print("Result : False")
# Out:
# Test Number 1 :
# Real Answer: 0 , Prediction: {'1': '100%'}, Result : False
# Test Number 2 :
# Real Answer: 1 , Prediction: {'0': '33%', '1': '66%'}, Result : False
# Test Number 3 :
# Real Answer: 1 , Prediction: {'0': '72%', '1': '27%'}, Result : False
# Test Number 4 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 5 :
# Real Answer: 0 , Prediction: {'1': '64%', '0': '35%'}, Result : False
# Test Number 6 :
# Real Answer: 0 , Prediction: {'1': '66%', '0': '33%'}, Result : False
# Test Number 7 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 8 :
# Real Answer: 0 , Prediction: {'1': '100%'}, Result : False
# Test Number 9 :
# Real Answer: 1 , Prediction: {'1': '83%', '0': '16%'}, Result : True
# Test Number 10 :
# Real Answer: 0 , Prediction: {'1': '50%', '0': '50%'}, Result : False
# Test Number 11 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 12 :
# Real Answer: 0 , Prediction: {'1': '9%', '0': '90%'}, Result : False
# Test Number 13 :
# Real Answer: 1 , Prediction: {'0': '80%', '1': '20%'}, Result : False
# Test Number 14 :
# Real Answer: 0 , Prediction: {'1': '59%', '0': '40%'}, Result : False
# Test Number 15 :
# Real Answer: 0 , Prediction: {'1': '44%', '0': '55%'}, Result : False
# Test Number 16 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 17 :
# Real Answer: 0 , Prediction: {'0': '75%', '1': '25%'}, Result : True
# Test Number 18 :
# Real Answer: 0 , Prediction: {'1': '83%', '0': '16%'}, Result : False
# Test Number 19 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 20 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 21 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 22 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 23 :
# Real Answer: 1 , Prediction: {'0': '80%', '1': '20%'}, Result : False
# Test Number 24 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 25 :
# Real Answer: 0 , Prediction: {'0': '81%', '1': '18%'}, Result : True
# Test Number 26 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 27 :
# Real Answer: 1 , Prediction: {'0': '50%', '1': '50%'}, Result : False
# Test Number 28 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 29 :
# Real Answer: 0 , Prediction: {'0': '81%', '1': '18%'}, Result : True
# Test Number 30 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 31 :
# Real Answer: 0 , Prediction: {'1': '59%', '0': '40%'}, Result : False
# Test Number 32 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 33 :
# Real Answer: 0 , Prediction: {'0': '81%', '1': '18%'}, Result : True
# Test Number 34 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 35 :
# Real Answer: 1 , Prediction: {'0': '71%', '1': '28%'}, Result : False
# Test Number 36 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 37 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 38 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 39 :
# Real Answer: 0 , Prediction: {'0': '80%', '1': '20%'}, Result : True
# Test Number 40 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 41 :
# Real Answer: 0 , Prediction: {'0': '50%', '1': '50%'}, Result : True
# Test Number 42 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 43 :
# Real Answer: 1 , Prediction: {'0': '33%', '1': '66%'}, Result : False
# Test Number 44 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 45 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 46 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 47 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 48 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 49 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 50 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 51 :
# Real Answer: 0 , Prediction: {'0': '75%', '1': '25%'}, Result : True
# Test Number 52 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 53 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 54 :
# Real Answer: 0 , Prediction: {'0': '81%', '1': '18%'}, Result : True
# Test Number 55 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 56 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 57 :
# Real Answer: 1 , Prediction: {'1': '83%', '0': '16%'}, Result : True
# Test Number 58 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 59 :
# Real Answer: 1 , Prediction: {'0': '57%', '1': '42%'}, Result : False
# Test Number 60 :
# Real Answer: 0 , Prediction: {'1': '40%', '0': '60%'}, Result : False
# Test Number 61 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 62 :
# Real Answer: 1 , Prediction: {'0': '88%', '1': '11%'}, Result : False
# Test Number 63 :
# Real Answer: 1 , Prediction: {'1': '40%', '0': '60%'}, Result : True
# Test Number 64 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 65 :
# Real Answer: 1 , Prediction: {'0': '75%', '1': '25%'}, Result : False
# Test Number 66 :
# Real Answer: 1 , Prediction: {'1': '64%', '0': '35%'}, Result : True
# Test Number 67 :
# Real Answer: 0 , Prediction: {'0': '81%', '1': '18%'}, Result : True
# Test Number 68 :
# Real Answer: 0 , Prediction: {'1': '100%'}, Result : False
# Test Number 69 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 70 :
# Real Answer: 0 , Prediction: {'0': '71%', '1': '28%'}, Result : True
# Test Number 71 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 72 :
# Real Answer: 0 , Prediction: {'0': '72%', '1': '27%'}, Result : True
# Test Number 73 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 74 :
# Real Answer: 1 , Prediction: {'1': '66%', '0': '33%'}, Result : True
# Test Number 75 :
# Real Answer: 1 , Prediction: {'0': '81%', '1': '18%'}, Result : False
# Test Number 76 :
# Real Answer: 0 , Prediction: {'0': '57%', '1': '42%'}, Result : True
# Test Number 77 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 78 :
# Real Answer: 1 , Prediction: {'1': '44%', '0': '55%'}, Result : True
# Test Number 79 :
# Real Answer: 1 , Prediction: {'1': '64%', '0': '35%'}, Result : True
# Test Number 80 :
# Real Answer: 0 , Prediction: {'0': '60%', '1': '40%'}, Result : True
# Test Number 81 :
# Real Answer: 0 , Prediction: {'1': '40%', '0': '60%'}, Result : False
# Test Number 82 :
# Real Answer: 0 , Prediction: {'0': '42%', '1': '57%'}, Result : True
# Test Number 83 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 84 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 85 :
# Real Answer: 0 , Prediction: {'1': '59%', '0': '40%'}, Result : False
# Test Number 86 :
# Real Answer: 1 , Prediction: {'1': '64%', '0': '35%'}, Result : True
# Test Number 87 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 88 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 89 :
# Real Answer: 0 , Prediction: {'1': '9%', '0': '90%'}, Result : False
# Test Number 90 :
# Real Answer: 0 , Prediction: {'0': '80%', '1': '20%'}, Result : True
# Test Number 91 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 92 :
# Real Answer: 0 , Prediction: {'1': '50%', '0': '50%'}, Result : False
# Test Number 93 :
# Real Answer: 1 , Prediction: {'1': '59%', '0': '40%'}, Result : True
# Test Number 94 :
# Real Answer: 1 , Prediction: {'1': '50%', '0': '50%'}, Result : True
# Test Number 95 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 96 :
# Real Answer: 1 , Prediction: {'1': '59%', '0': '40%'}, Result : True
# Test Number 97 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 98 :
# Real Answer: 1 , Prediction: {'0': '88%', '1': '11%'}, Result : False
# Test Number 99 :
# Real Answer: 1 , Prediction: {'1': '59%', '0': '40%'}, Result : True
# Test Number 100 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 101 :
# Real Answer: 1 , Prediction: {'1': '59%', '0': '40%'}, Result : True
# Test Number 102 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 103 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 104 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 105 :
# Real Answer: 1 , Prediction: {'0': '72%', '1': '27%'}, Result : False
# Test Number 106 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 107 :
# Real Answer: 0 , Prediction: {'0': '81%', '1': '18%'}, Result : True
# Test Number 108 :
# Real Answer: 0 , Prediction: {'1': '66%', '0': '33%'}, Result : False
# Test Number 109 :
# Real Answer: 0 , Prediction: {'1': '66%', '0': '33%'}, Result : False
# Test Number 110 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 111 :
# Real Answer: 0 , Prediction: {'1': '100%'}, Result : False
# Test Number 112 :
# Real Answer: 0 , Prediction: {'1': '60%', '0': '40%'}, Result : False
# Test Number 113 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 114 :
# Real Answer: 0 , Prediction: {'1': '50%', '0': '50%'}, Result : False
# Test Number 115 :
# Real Answer: 0 , Prediction: {'0': '80%', '1': '20%'}, Result : True
# Test Number 116 :
# Real Answer: 0 , Prediction: {'0': '80%', '1': '20%'}, Result : True
# Test Number 117 :
# Real Answer: 0 , Prediction: {'1': '59%', '0': '40%'}, Result : False
# Test Number 118 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 119 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 120 :
# Real Answer: 0 , Prediction: {'1': '9%', '0': '90%'}, Result : False
# Test Number 121 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 122 :
# Real Answer: 1 , Prediction: {'0': '88%', '1': '11%'}, Result : False
# Test Number 123 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 124 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 125 :
# Real Answer: 1 , Prediction: {'1': '64%', '0': '35%'}, Result : True
# Test Number 126 :
# Real Answer: 1 , Prediction: {'0': '42%', '1': '57%'}, Result : False
# Test Number 127 :
# Real Answer: 0 , Prediction: {'0': '42%', '1': '57%'}, Result : True
# Test Number 128 :
# Real Answer: 0 , Prediction: {'0': '81%', '1': '18%'}, Result : True
# Test Number 129 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 130 :
# Real Answer: 0 , Prediction: {'0': '42%', '1': '57%'}, Result : True
# Test Number 131 :
# Real Answer: 0 , Prediction: {'0': '71%', '1': '28%'}, Result : True
# Test Number 132 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 133 :
# Real Answer: 0 , Prediction: {'0': '80%', '1': '20%'}, Result : True
# Test Number 134 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 135 :
# Real Answer: 0 , Prediction: {'1': '40%', '0': '60%'}, Result : False
# Test Number 136 :
# Real Answer: 1 , Prediction: {'0': '50%', '1': '50%'}, Result : False
# Test Number 137 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 138 :
# Real Answer: 1 , Prediction: {'0': '88%', '1': '11%'}, Result : False
# Test Number 139 :
# Real Answer: 1 , Prediction: {'0': '72%', '1': '27%'}, Result : False
# Test Number 140 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 141 :
# Real Answer: 0 , Prediction: {'1': '66%', '0': '33%'}, Result : False
# Test Number 142 :
# Real Answer: 1 , Prediction: {'0': '80%', '1': '20%'}, Result : False
# Test Number 143 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 144 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 145 :
# Real Answer: 1 , Prediction: {'1': '60%', '0': '40%'}, Result : True
# Test Number 146 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 147 :
# Real Answer: 1 , Prediction: {'0': '33%', '1': '66%'}, Result : False
# Test Number 148 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 149 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 150 :
# Real Answer: 0 , Prediction: {'1': '100%'}, Result : False
# Test Number 151 :
# Real Answer: 1 , Prediction: {'0': '78%', '1': '21%'}, Result : False
# Test Number 152 :
# Real Answer: 0 , Prediction: {'0': '50%', '1': '50%'}, Result : True
# Test Number 153 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 154 :
# Real Answer: 0 , Prediction: {'1': '44%', '0': '55%'}, Result : False
# Test Number 155 :
# Real Answer: 1 , Prediction: {'0': '88%', '1': '11%'}, Result : False
# Test Number 156 :
# Real Answer: 1 , Prediction: {'0': '100%'}, Result : False
# Test Number 157 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 158 :
# Real Answer: 0 , Prediction: {'0': '80%', '1': '20%'}, Result : True
# Test Number 159 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 160 :
# Real Answer: 0 , Prediction: {'1': '9%', '0': '90%'}, Result : False
# Test Number 161 :
# Real Answer: 1 , Prediction: {'1': '100%'}, Result : True
# Test Number 162 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True
# Test Number 163 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 164 :
# Real Answer: 0 , Prediction: {'0': '88%', '1': '11%'}, Result : True
# Test Number 165 :
# Real Answer: 1 , Prediction: {'1': '66%', '0': '33%'}, Result : True
# Test Number 166 :
# Real Answer: 1 , Prediction: {'1': '66%', '0': '33%'}, Result : True
# Test Number 167 :
# Real Answer: 1 , Prediction: {'0': '72%', '1': '27%'}, Result : False
# Test Number 168 :
# Real Answer: 0 , Prediction: {'0': '100%'}, Result : True

# %%
print("Number Of Right Answers: ", counter)
print("Number Of Tests: ", testing_data.__len__())
print("Accuracy: ", (counter / testing_data.__len__()) * 100, "%")
# Out:
# Number Of Right Answers:  109
# Number Of Tests:  168
# Accuracy:  64.88095238095238 %
